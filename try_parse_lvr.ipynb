# %% [markdown]
# # lvr parser

# %% [markdown]
# ### Download files
#
# http://plvr.land.moi.gov.tw/DownloadOpenData

# %%
from functools import reduce
import pandas as pd
import requests
from pathlib import Path
from clint.textui import progress
import zipfile
import os
import re

# %%
def download_file(url, path):
    r = requests.head(url)
    filename = r.headers.get('Content-Disposition').split('=')[-1].replace('"', '')
    total_length = int(r.headers.get('content-length'))
    
    local_filename = Path(path).expanduser() / filename
    
    print(f'Saving file to "{local_filename}..."')
    # NOTE the stream=True parameter
    r = requests.get(url, stream=True)
    with open(local_filename, 'wb') as f:
        for chunk in progress.bar(r.iter_content(chunk_size=1024), expected_size=(total_length/1024) + 1): 
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush() # commented by recommendation from J.F.Sebastian
    return True

# %%
url_base = 'http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName={year}S{season}'

want_data = [('105', '1'), ('105', '2'), ('105', '3'), ('105', '4'), ('106', '1'), ('106', '2'), ('106', '3')]
urls = [url_base.format(year=d[0], season=d[1]) for d in want_data]
urls
# Out:
# ['http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName=105S1',
#  'http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName=105S2',
#  'http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName=105S3',
#  'http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName=105S4',
#  'http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName=106S1',
#  'http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName=106S2',
#  'http://plvr.land.moi.gov.tw/DownloadHistory?type=season&fileName=106S3']

# %%
# for url in urls:
#     download_file(url, './data')
# Out:
# Saving file to "data/2016S1.zip..."
# Saving file to "data/2016S2.zip..."
# Saving file to "data/2016S3.zip..."
# Saving file to "data/2016S4.zip..."
# Saving file to "data/2017S1.zip..."
# Saving file to "data/2017S2.zip..."
# Saving file to "data/2017S3.zip..."

# %% [markdown]
# ### Unzip

# %%
zip_files = list(Path('./data').glob('*S*.zip'))
zip_files
# Out:
# [PosixPath('data/2017S1.zip'),
#  PosixPath('data/2016S1.zip'),
#  PosixPath('data/2017S3.zip'),
#  PosixPath('data/2016S3.zip'),
#  PosixPath('data/2016S2.zip'),
#  PosixPath('data/2016S4.zip'),
#  PosixPath('data/2017S2.zip')]

# %%
p = zip_files[0]
dest_folder = p.parent / p.stem

# %%
# !cd data; ls
# Out:
# 2016S1.zip  2016S4.zip	2017S2.zip  df_all_2017S3.csv
# 2016S2.zip  2017S1	2017S3	    df_all_2017S3_geocode.csv
# 2016S3.zip  2017S1.zip	2017S3.zip  dt_2017S3_geo_codebase.csv

# %%
overwrite = True

if dest_folder.exists() and overwrite:
    dest_folder.mkdir(exist_ok=True)
    
    with zipfile.ZipFile(p.as_posix(), 'r') as zip_ref:
        print('Unzip file {}...'.format(p.as_posix()))
        zip_ref.extractall(dest_folder.as_posix())
        print('Finished')
elif dest_folder.exists() and not overwrite:
    raise FileExistsError(dest_folder.as_posix())
# Out:
# Unzip file data/2017S1.zip...
# Finished

# %%
def unzip_lvr(zip_files, overwrite=True):
    for p in zip_files:
        p = Path(p)
        dest_folder = p.parent / p.stem; print(dest_folder)
        
        if not dest_folder.exists() or overwrite:
            dest_folder.mkdir(exist_ok=True)

            with zipfile.ZipFile(p.as_posix(), 'r') as zip_ref:
                print('Unzip file {}...'.format(p.as_posix()))
                zip_ref.extractall(dest_folder.as_posix())
                print('Finished')
        elif dest_folder.exists() and not overwrite:
            raise FileExistsError(dest_folder.as_posix())
            
    return True

# %%
unzip_lvr(zip_files)
# Out:
# data/2017S1
# Unzip file data/2017S1.zip...
# Finished
# data/2016S1
# Unzip file data/2016S1.zip...
# Finished
# data/2017S3
# Unzip file data/2017S3.zip...
# Finished
# data/2016S3
# Unzip file data/2016S3.zip...
# Finished
# data/2016S2
# Unzip file data/2016S2.zip...
# Finished
# data/2016S4
# Unzip file data/2016S4.zip...
# Finished
# data/2017S2
# Unzip file data/2017S2.zip...
# Finished
# True

# %% [markdown]
# ---

# %% [markdown]
# ### List csv files

# %%
print(os.listdir(DEST_FOLDER)[:10], '\n\n-----------------\n')
dest_folder = Path(DEST_FOLDER)

csv_files = [f.as_posix() for f in dest_folder.glob('*.CSV') if re.search(r'land_[AB].CSV$', f.as_posix())]
csv_files.sort()

print('\n'.join(csv_files))
# Out:
# ['F_lvr_land_A.XML', 'I_lvr_land_C_LAND.XML', 'A_lvr_land_A_LAND.TXT', 'Q_lvr_land_A_LAND.CSV', 'O_lvr_land_C_LAND.CSV', 'J_lvr_land_B_LAND.XML', 'J_lvr_land_C.XML', 'U_lvr_land_C.CSV', 'C_lvr_land_A_LAND.XML', 'M_lvr_land_A_BUILD.XML']
#
# -----------------
#
# data/2017S3/A_lvr_land_A.CSV
# data/2017S3/A_lvr_land_B.CSV
# data/2017S3/B_lvr_land_A.CSV
# data/2017S3/B_lvr_land_B.CSV
# data/2017S3/C_lvr_land_A.CSV
# data/2017S3/C_lvr_land_B.CSV
# data/2017S3/D_lvr_land_A.CSV
# data/2017S3/D_lvr_land_B.CSV
# data/2017S3/E_lvr_land_A.CSV
# data/2017S3/E_lvr_land_B.CSV
# data/2017S3/F_lvr_land_A.CSV
# data/2017S3/F_lvr_land_B.CSV
# data/2017S3/G_lvr_land_A.CSV
# data/2017S3/G_lvr_land_B.CSV
# data/2017S3/H_lvr_land_A.CSV
# data/2017S3/H_lvr_land_B.CSV
# data/2017S3/I_lvr_land_A.CSV
# data/2017S3/I_lvr_land_B.CSV
# data/2017S3/J_lvr_land_A.CSV
# data/2017S3/J_lvr_land_B.CSV
# data/2017S3/K_lvr_land_A.CSV
# data/2017S3/K_lvr_land_B.CSV
# data/2017S3/M_lvr_land_A.CSV
# data/2017S3/M_lvr_land_B.CSV
# data/2017S3/N_lvr_land_A.CSV
# data/2017S3/N_lvr_land_B.CSV
# data/2017S3/O_lvr_land_A.CSV
# data/2017S3/O_lvr_land_B.CSV
# data/2017S3/P_lvr_land_A.CSV
# data/2017S3/P_lvr_land_B.CSV
# data/2017S3/Q_lvr_land_A.CSV
# data/2017S3/Q_lvr_land_B.CSV
# data/2017S3/T_lvr_land_A.CSV
# data/2017S3/T_lvr_land_B.CSV
# data/2017S3/U_lvr_land_A.CSV
# data/2017S3/U_lvr_land_B.CSV
# data/2017S3/V_lvr_land_A.CSV
# data/2017S3/V_lvr_land_B.CSV
# data/2017S3/W_lvr_land_A.CSV
# data/2017S3/W_lvr_land_B.CSV
# data/2017S3/X_lvr_land_A.CSV
# data/2017S3/X_lvr_land_B.CSV
# data/2017S3/Z_lvr_land_A.CSV
# data/2017S3/Z_lvr_land_B.CSV

# %% [markdown]
# ---

# %% [markdown]
# ### Parse data

# %%
import pandas as pd

# %%
# !cd data/2017S3/ && iconv_ext.sh cp950 utf-8

def pd_read_csv_cp950(file):
    try:
        df = pd.read_csv(file, encoding='cp950')
    except Exception as e:
        from io import StringIO
        with open(file , "rb") as  fin :
            text = fin.read()
            text = text.decode('cp950', errors='ignore')
            df = pd.read_csv(StringIO(text))
#         print(f, '---', e)
    return df

# %%
def pd_read_lrv(file):
    
    county_dict = dict(
        [('C', '基隆市'),
        ('A', '臺北市'),
        ('F', '新北市'),
        ('H', '桃園縣'),
        ('O', '新竹市'),
        ('J', '新竹縣'),
        ('K', '苗栗縣'),
        ('B', '臺中市'),
        ('M', '南投縣'),
        ('N', '彰化縣'),
        ('P', '雲林縣'),
        ('I', '嘉義市'),
        ('Q', '嘉義縣'),
        ('D', '臺南市'),
        ('E', '高雄市'),
        ('T', '屏東縣'),
        ('G', '宜蘭縣'),
        ('U', '花蓮縣'),
        ('V', '臺東縣'),
        ('X', '澎湖縣'),
        ('W', '金門縣'),
        ('Z', '連江縣')]
    )
    county_code = file.split('/')[-1][0]
    county = county_dict.get(county_code)
    df = pd_read_csv_cp950(file)
    df.insert(loc=0, column='county', value=county)
    return df

# %%
pd_read_lrv('data/2017S3/B_lvr_land_C.CSV')
# Out:
#     county 鄉鎮市區          租賃標的                 土地區段位置或建物區門牌  租賃總面積平方公尺  \
# 0      臺中市  西屯區     房地(土地+建物)           臺中市西屯區長安路二段91~120號      95.00
# 1      臺中市  西屯區     房地(土地+建物)           臺中市西屯區長安路二段91~120號      95.00
# 2      臺中市  西屯區     房地(土地+建物)            臺中市西屯區西安街151~180號      74.00
# 3      臺中市   北區  房地(土地+建物)+車位          臺中市北區文昌東二街116巷1~30號      22.94
# 4      臺中市  梧棲區            土地                 忠孝段451~480地號    3093.00
# 5      臺中市  西屯區     房地(土地+建物)             臺中市西屯區河南路二段1~30號      25.20
# 6      臺中市  梧棲區     房地(土地+建物)           臺中市梧棲區民生西街181~210號     115.23
# 7      臺中市   西區     房地(土地+建物)           臺中市西區三民路一段50巷1~30號       2.73
# 8      臺中市  北屯區  房地(土地+建物)+車位           臺中市北屯區軍福七路151~180號      20.76
# 9      臺中市  南屯區     房地(土地+建物)            臺中市南屯區大英街601~630號     289.26
# 10     臺中市  西屯區            土地                   龍富段61~90地號     485.66
# 11     臺中市  南屯區     房地(土地+建物)           臺中市南屯區大墩十街241~270號      14.39
# 12     臺中市  南屯區     房地(土地+建物)              臺中市南屯區精科東路1~30號    3414.88
# 13     臺中市  南屯區     房地(土地+建物)              臺中市南屯區精科七路1~30號    1223.50
# 14     臺中市  西屯區     房地(土地+建物)            臺中市西屯區漢成街121~150號      19.67
# 15     臺中市  西屯區     房地(土地+建物)             臺中市南屯區西屯路二段1~30號     101.91
# 16     臺中市  西屯區  房地(土地+建物)+車位            臺中市西屯區朝富路151~180號     155.37
# 724       其他       NaN       NaN  1060701  土地1建物1車位0         ...
# 725       其他       NaN       NaN  1060701  土地1建物1車位0         ...
# 726        農       NaN       NaN  1060706  土地1建物0車位0         ...
# 727        商       NaN       NaN  1060720  土地1建物1車位0         ...
# 728        住       NaN       NaN  1060715  土地1建物1車位0         ...
# 729        商       NaN       NaN  1060629  土地0建物1車位1         ...
# 730        住       NaN       NaN  1060708  土地1建物1車位0         ...
# 731        商       NaN       NaN  1060701  土地1建物1車位0         ...
# 732        商       NaN       NaN  1060706  土地1建物1車位0         ...
# 733        商       NaN       NaN  1060705  土地1建物1車位0         ...
# 734        商       NaN       NaN  1060716  土地1建物1車位0         ...
# 735      NaN       NaN       NaN  1060720  土地0建物1車位0         ...
# 736        住       NaN       NaN  1060714  土地0建物1車位0         ...
# 737        住       NaN       NaN  1060719  土地0建物1車位0         ...
# 738        住       NaN       NaN  1060719  土地0建物1車位0         ...
# 739        住       NaN       NaN  1060701  土地1建物1車位0         ...
# 740        住       NaN       NaN  1060718  土地1建物1車位0         ...
# 741      NaN       NaN       NaN  1060726  土地0建物1車位0         ...
# 742        住       NaN       NaN  1060726  土地1建物1車位1         ...
# 743       其他       NaN       NaN  1060609  土地1建物1車位1         ...
# 744        住       NaN       NaN  1060630  土地1建物0車位0         ...
#
#     建物現況格局-隔間  有無管理組織 有無附傢俱     總額元 單價每平方公尺  車位類別  租賃總面積平方公尺.2  租金總額元  \
# 0           有       無     有   15000   185.0   NaN         0.00      0
# 1           有       無     有   11000    94.0   NaN         0.00      0
# 2           無       無     無   63000   472.0   NaN         0.00      0
# 3           有       有     無   20000   113.0  坡道平面        41.14      0
# 4           有       無     無   11500     4.0   NaN         0.00      0
# 5           有       無     有   12000    61.0   NaN         0.00      0
# 6           有       無     無   15000    80.0   NaN         0.00      0
# 7           有       有     有    4000   113.0   NaN         0.00      0
# 8           有       無     有   25000   137.0  坡道平面        27.05      0
# 9           無       無     無   60000   207.0   NaN         0.00      0
# 10          有       無     無   60000   124.0   NaN         0.00      0
# 11          有       有     無   24000   122.0   NaN         0.00      0
# 12          無       無     無  500000     NaN   NaN         0.00      0
# 13          無       無     有  320000     NaN   NaN         0.00      0
# 14          無       有     無   14000   122.0   NaN         0.00      0
# 15          無       無     無  140000   532.0   NaN         0.00      0
# 16          有       有     有   65000   210.0  坡道平面         0.00      0
# 17          有       有     有   20000   255.0  坡道機械         6.48      0
# 18          有       有     有   38000   134.0  坡道平面         0.00      0
# 19          有       有     有   18000   105.0  坡道平面        38.22      0
# 20          無       有     有   60000    45.0  坡道平面         0.00      0
# 21          無       有     無   38000   134.0  坡道平面         0.00      0
# 22          有       有     有    6500   155.0   NaN         0.00      0
# 23          有       無     無   19000   228.0   NaN         0.00      0
# 24          有       無     有    7500   903.0   NaN         0.00      0
# 25          有       無     無   19000   228.0   NaN         0.00      0
# 26          有       有     無    5800   161.0   NaN         0.00      0
# 27          有       有     有   20000   298.0  坡道平面         0.00      0
# 28          有       無     無   38000   299.0   NaN         0.00      0
# 29          無       有     無   30000   129.0  坡道機械         0.00      0
# ..        ...     ...   ...     ...     ...   ...          ...    ...
# 715         有       無     無  100000    73.0   NaN         0.00      0
# 716         有       有     有   24000   144.0   NaN         0.00      0
# 717         有       有     有   22000   202.0  坡道機械         0.00      0
# 718         無       有     無   15400   194.0   NaN         0.00      0
# 719         有       有     有    6000   175.0   NaN         0.00      0
# 720         有       有     有   15000   140.0   NaN         0.00      0
# 721         無       無     有   10000   204.0   NaN         0.00      0
# 722         有       無     有   56000   188.0  坡道平面         0.00      0
# 723         有       有     有   22000   202.0   NaN         0.00      0
# 724         無       無     無  140000   259.0   NaN         0.00      0
# 725         無       無     無  140000   148.0   NaN         0.00      0
# 726         有       無     無   55000   111.0   NaN         0.00      0
# 727         有       無     無   35000   271.0   NaN         0.00      0
# 728         有       無     無    7500   197.0   NaN         0.00      0
# 729         有       有     有   36000   164.0  坡道平面        34.09      0
# 730         無       有     無   15000   278.0   NaN         0.00      0
# 731         有       有     有    5200   172.0   NaN         0.00      0
# 732         有       有     有    8000   129.0   NaN         0.00      0
# 733         有       有     有    5500   193.0   NaN         0.00      0
# 734         有       有     有    8000   274.0   NaN         0.00      0
# 735         無       有     無   34000   120.0   NaN         0.00      0
# 736         有       有     有   17500   154.0   NaN         0.00      0
# 737         有       無     無    7000   105.0   NaN         0.00      0
# 738         有       無     無   18000   361.0   NaN         0.00      0
# 739         無       有     無   19000   391.0   NaN         0.00      0
# 740         無       有     無   25000   369.0   NaN         0.00      0
# 741         有       無     有    8000   198.0   NaN         0.00      0
# 742         有       無     有   17000   189.0  坡道機械         0.00      0
# 743         有       有     無   60000   228.0  坡道平面        26.48      0
# 744         有       無     無   60000   333.0   NaN         0.00      0
#
#                                                     備註                   編號
# 0                                                  NaN  RPPPMLLJNHMFFCB67CC
# 1                                                  NaN  RPQPMLLJNHMFFCB77CC
# 2                                                  NaN  RPRPMLLJNHMFFCB87CC
# 3                                                  NaN  RPWNMLLJNHMFFBB08CC
# 4                                                  NaN  RPVNMLLJNHMFFCL09CC
# 5                                                  NaN  RPXOMLLJNHMFFCB48DC
# 6                                                  NaN  RPWNMLLJNHMFFCL66DC
# 7                                                  NaN  RPQNMLMJNHMFFAB47CC
# 8                                                  NaN  RPRNMLMJNHMFFBB67CC
# 9    1.106年8月1日起至109年4月30日，每月租金陸萬元整。2.109年5月1日起至113...  RPORMLMJNHMFFCB87CC
# 10                                                 NaN  RPQRMLMJNHMFFCB08CC
# 11                                起租日:106/05/10租金總額含稅。  RPVRMLMJNHMFFCB58CC
# 12                        只承租本地號面積約3414.88平方公尺(約1033坪)  RPQSMLMJNHMFFCB18CC
# 13   109年5月1日~112年4月30日租金為35萬元112年5月1日~116年4月30日租金為...  RPPNMLNJNHMFFCB67CC
# 14                                                 NaN  RPPOMLNJNHMFFCB77CC
# 15                                                 NaN  RPTOMLNJNHMFFCB18CC
# 16                                                 NaN  RPPPMLNJNHMFFCB87CC
# 17                                                 NaN  RPRQMLNJNHMFFCB18CC
# 18                                                 NaN  RPTQMLNJNHMFFCB38CC
# 19                                                 NaN  RPQNMLNJNHMFFBB67CC
# 20          如因租賃標的物結構問題，無法通過建築物公共安全檢查及消防安全檢查，雙方同意終止租約。  RPTNMLNJNHMFFBB97CC
# 21                                                 NaN  RPPPMLNJNHMFFBB77CC
# 22                                 此建物有隔成三間套房，所以面積除以3。  RPWPMLNJNHMFFAB38CC
# 23                           地上有4層樓未保存建物，承租其中1至3樓部分面積。  RPPOMLNJNHMFFAL58CC
# 24                               地上有4層樓未保存建物，承租4樓套房1間。  RPQOMLNJNHMFFAL68CC
# 25                           地上有4層樓未保存建物，承租其中1至3樓部分面積。  RPROMLNJNHMFFAL78CC
# 26                                                 NaN  RPPOMLOJNHMFFAB77DC
# 27                                                 NaN  RPRNMLOJNHMFFAB77CC
# 28                                                 NaN  RPQOMLOJNHMFFAB77CC
# 29                                                 NaN  RPOPMLOJNHMFFBB77CC
# ..                                                 ...                  ...
# 715                                                NaN  RPUPMLQLPHMFFCB09CC
# 716                                                NaN  RPOQMLQLPHMFFCB58CC
# 717                                                NaN  RPPQMLQLPHMFFCB68CC
# 718                                                NaN  RPTOMLQLPHMFFBB78CC
# 719                                                NaN  RPWOMLQLPHMFFBB09CC
# 720                                                NaN  RPPPMLQLPHMFFBB48CC
# 721                                                NaN  RPQQMLQLPHMFFBB68CC
# 722                                                NaN  RPTOMLQLPHMFFAB68CC
# 723                                            租金含管理費。  RPXPMLQLPHMFFAB56CC
# 724                                                NaN  RPQNMLRLPHMFFDB68CC
# 725                                                NaN  RPRNMLRLPHMFFDB78CC
# 726  只承租本土地面積約495.87平方公尺(約150坪),地上建物約439.67平方公尺(約13...  RPXOMLRLPHMFFCB76CC
# 727                                                NaN  RPPOMLRLPHMFFDB78DC
# 728                                                NaN  RPTNMLSLPHMFFJB07CC
# 729                                                NaN  RPXOMLSLPHMFFBB76CC
# 730                                                NaN  RPXPMLSLPHMFFBB86CC
# 731                                                NaN  RPQNMLTLPHMFFAB58CC
# 732                                                NaN  RPRNMLTLPHMFFAB68CC
# 733                                                NaN  RPSNMLTLPHMFFAB78CC
# 734                                               含管理費  RPUNMLTLPHMFFAB98CC
# 735                                                NaN  RPXNMLLMPHMFFAB58CC
# 736                                                NaN  RPWOMLLMPHMFFAB58CC
# 737                                                NaN  RPROMLLMPHMFFDB38CC
# 738                                                NaN  RPSOMLLMPHMFFDB48CC
# 739                                            承租一樓及騎樓  RPROMLLMPHMFFCB28CC
# 740                                               含管理費  RPWOMLLMPHMFFCB78CC
# 741                                                NaN  RPQPMLLMPHMFFCB28CC
# 742                                     含管理費,機下車位B2-19  RPRPMLLMPHMFFCB38CC
# 743                                                NaN  RPXRMLLMPHMFFCB56CC
# 744                               本出租標的物有使用執照，但建物無保存登記  RPOSMLLMPHMFFCB38CC
#
# [745 rows x 30 columns]

# %%
dfs = [pd_read_lrv(f) for f in csv_files]

# %%
# list(map(lambda x: x.shape, dfs))

# %%
df_all = reduce(lambda x, y: pd.concat([x, y], axis=0), dfs)

# %%
dfs
df_all.shape[1]
# Out:
# 29

# %%
assert df_all.shape[1] == 29, 'Dimension error'

# %%
df_all.head()
# Out:
#   county 鄉鎮市區       交易標的           土地區段位置或建物區門牌  土地移轉總面積平方公尺 都市土地使用分區  \
# 0    臺北市  文山區  房地(土地+建物)  臺北市文山區保儀路109巷23弄1~30號        14.50        住
# 1    臺北市  中正區  房地(土地+建物)   臺北市中正區中華路二段313巷1~30號        10.53        住
# 2    臺北市  文山區         車位      臺北市文山區興順街151~180號         4.60        住
# 3    臺北市  文山區  房地(土地+建物)      臺北市文山區景中街30巷1~30號         1.24       其他
# 4    臺北市  萬華區  房地(土地+建物)       臺北市萬華區峨眉街91~120號         3.10        商
#
#   非都市土地使用分區 非都市土地使用編定    交易年月日      交易筆棟數         ...          建物現況格局-衛  \
# 0       NaN       NaN  1060208  土地1建物1車位0         ...                 1
# 1       NaN       NaN  1060409  土地1建物1車位0         ...                 1
# 2       NaN       NaN  1060320  土地0建物0車位1         ...                 0
# 3       NaN       NaN  1060415  土地1建物1車位0         ...                 0
# 4       NaN       NaN  1060308  土地1建物1車位0         ...                 2
#
#   建物現況格局-隔間 有無管理組織      總價元   單價每平方公尺  車位類別  車位移轉總面積平方公尺    車位總價元          備註  \
# 0         有      無  7280000   82549.0   NaN         0.00        0  含增建或未登記建物。
# 1         有      無  4000000  156067.0   NaN         0.00        0         NaN
# 2         有      有  1350000       NaN  坡道平面        36.13  1350000         NaN
# 3         無      有  1000000  110497.0   NaN         0.00        0         NaN
# 4         有      有  7250000  234780.0   NaN         0.00        0  含增建或未登記建物。
#
#                     編號
# 0  RPSOMLMJNHMFFAA47CA
# 1  RPPNMLPJNHMFFAA37CA
# 2  RPRNMLTJNHMFFAA97CA
# 3  RPUSMLPKNHMFFAA48CA
# 4  RPPPMLMJNHMFFBA37CA
#
# [5 rows x 29 columns]

# %%
df_all['county'].value_counts()
# Out:
# 新北市    13549
# 臺中市    11329
# 桃園縣    10512
# 高雄市    10145
# 臺南市     6733
# 臺北市     5396
# 彰化縣     3193
# 屏東縣     2479
# 新竹縣     2456
# 雲林縣     2145
# 苗栗縣     2130
# 新竹市     1790
# 嘉義縣     1694
# 宜蘭縣     1649
# 南投縣     1628
# 基隆市     1239
# 花蓮縣     1095
# 嘉義市      896
# 臺東縣      749
# 金門縣      309
# 澎湖縣      281
# 連江縣       11
# Name: county, dtype: int64

# %% [markdown]
# ## Export

# %%
# df_all.to_csv('data/df_all_2017S3.csv', encoding='utf-8', index=False)

# %% [markdown]
# ---

# %%
def pd_read_csv_cp950(file):
    try:
        df = pd.read_csv(file, encoding='cp950')
    except Exception as e:
        from io import StringIO
        with open(file , "rb") as  fin :
            text = fin.read()
            text = text.decode('cp950', errors='ignore')
            df = pd.read_csv(StringIO(text), error_bad_lines=False)
    return df

def pd_read_lrv(file):
    
    county_dict = dict(
        [('C', '基隆市'),
        ('A', '臺北市'),
        ('F', '新北市'),
        ('H', '桃園縣'),
        ('O', '新竹市'),
        ('J', '新竹縣'),
        ('K', '苗栗縣'),
        ('B', '臺中市'),
        ('M', '南投縣'),
        ('N', '彰化縣'),
        ('P', '雲林縣'),
        ('I', '嘉義市'),
        ('Q', '嘉義縣'),
        ('D', '臺南市'),
        ('E', '高雄市'),
        ('T', '屏東縣'),
        ('G', '宜蘭縣'),
        ('U', '花蓮縣'),
        ('V', '臺東縣'),
        ('X', '澎湖縣'),
        ('W', '金門縣'),
        ('Z', '連江縣')]
    )
    county_code = file.split('/')[-1][0]
    county = county_dict.get(county_code)
    df = pd_read_csv_cp950(file)
    df.insert(loc=0, column='county', value=county)
    return df

def read_and_combine(folder):

    print('Processing...', str(folder))
    dest_folder = Path(folder)

    csv_files = [f.as_posix() for f in dest_folder.glob('*.CSV') if re.search(r'land_[AB].CSV$', f.as_posix())]
    csv_files.sort()

    dfs = [pd_read_lrv(f) for f in csv_files]
    for df in dfs:
#         print(df.shape)
        if df.shape[1] != 29:
            print(df.head())
            raise Exception('Dimension error')
    
    df_all = reduce(lambda x, y: pd.concat([x, y], axis=0), dfs)

    # Export to csv
    df_all.to_csv(dest_folder.with_suffix('.csv').as_posix(), encoding='utf-8', index=False)
    
    print(df_all.shape)
    return df_all

# %%
read_and_combine('./data/2016S1/')
read_and_combine('./data/2016S2/')
read_and_combine('./data/2016S3/')
read_and_combine('./data/2016S4/')
read_and_combine('./data/2017S1/')
# Out:
# Processing... ./data/2016S1/
# b'Skipping line 1420: expected 28 fields, saw 29\nSkipping line 1454: expected 28 fields, saw 29\nSkipping line 1455: expected 28 fields, saw 29\nSkipping line 1456: expected 28 fields, saw 29\nSkipping line 1457: expected 28 fields, saw 29\nSkipping line 1458: expected 28 fields, saw 29\nSkipping line 1512: expected 28 fields, saw 29\nSkipping line 1559: expected 28 fields, saw 29\nSkipping line 1560: expected 28 fields, saw 29\nSkipping line 1561: expected 28 fields, saw 29\nSkipping line 3251: expected 28 fields, saw 29\n'
# (96946, 29)
# Processing... ./data/2016S2/
# (54881, 29)
# Processing... ./data/2016S3/
# b'Skipping line 1148: expected 28 fields, saw 29\n'
# (76494, 29)
# Processing... ./data/2016S4/
# (70711, 29)
# Processing... ./data/2017S1/
# (78475, 29)
# Processing... ./data/2017S2/
# b'Skipping line 661: expected 28 fields, saw 29\nSkipping line 726: expected 28 fields, saw 29\nSkipping line 1883: expected 28 fields, saw 29\nSkipping line 1884: expected 28 fields, saw 29\n'
# (66949, 29)
#     county 鄉鎮市區          交易標的             土地區段位置或建物區門牌  土地移轉總面積平方公尺 都市土地使用分區  \
# 0      臺北市  中正區     房地(土地+建物)           臺北市中正區金門街1~30號        10.71        住
# 1      臺北市  文山區            土地           政大段二小段91~120地號       104.00       其他
# 2      臺北市  中正區     房地(土地+建物)           臺北市中正區金華街1~30號        12.88        商
# 3      臺北市  中正區            車位      臺北市中正區羅斯福路二段8巷1~30號         0.15        住
# 4      臺北市  中正區     房地(土地+建物)        臺北市中正區新生南路一段1~30號        15.23       其他
# 5      臺北市  萬華區     房地(土地+建物)        臺北市萬華區長沙街二段31~60號        17.00        商
# 6      臺北市  中正區  房地(土地+建物)+車位      臺北市中正區中華路一段95巷1~30號        20.92        商
# 6           無      無  78500000  302036.0  坡道平面        91.27  6700000
# 7           有      有  10600000  138635.0   NaN         0.00        0
# 8           有      有  10400000  157887.0   NaN         0.00        0
# 9           有      無   7300000  172863.0   NaN         0.00        0
# 10          無      有  32900000  311818.0  坡道平面        52.71  2900000
# 11          有      有  15680000   90333.0  坡道平面         0.00        0
# 12          有      有   1500000       NaN  坡道平面        31.40  1500000
# 13          有      無  23800000  170744.0  坡道機械         0.00        0
# 14          有      有   5100000  141392.0   NaN         0.00        0
# 15          有      有  23000000  208768.0  坡道平面         0.00        0
# 16          有      有   7100000  187781.0   NaN         0.00        0
# 17          有      有  13000000  230824.0  坡道機械         0.00        0
# 18          有      有  20160000  197106.0   NaN         0.00        0
# 19          有      有  14260000  178652.0   NaN         0.00        0
# 20          有      有  26200000  192251.0   NaN         0.00        0
# 21          有      有  23400000  181522.0   NaN         0.00        0
# 22          有      無  11080000  154017.0   NaN         0.00        0
# 23          無      無  25000000  225958.0   NaN         0.00        0
# 24          有      無  14660000  153846.0   NaN         0.00        0
# 25          有      有  21000000  163386.0   NaN         0.00        0
# 26          有      無  13000000  204370.0   NaN         0.00        0
# 27          有      有  25000000  156671.0  坡道平面         0.00        0
# 28          無      有  37255000  208268.0   NaN         0.00        0
# 29          有      有  27500000  141098.0  坡道平面         0.00        0
# ..        ...    ...       ...       ...   ...          ...      ...
# 172         有      無      7355    7005.0   NaN         0.00        0
# 173         有      無  31000000  119231.0   NaN         0.00        0
# 174         有      無   2700000    1796.0   NaN         0.00        0
# 175         有      無   3360000   35733.0   NaN         0.00        0
# 176         有      無   9000000   32835.0   NaN         0.00        0
# 177         有      無  28800000  190011.0   NaN         0.00        0
# 178         有      無      7355    7005.0   NaN         0.00        0
# 179         有      無      7355    7005.0   NaN         0.00        0
# 180         有      無   7480000    6022.0   NaN         0.00        0
# 181         有      無   1000000    3246.0   NaN         0.00        0
# 182         有      無   2740000    3739.0   NaN         0.00        0
# 183         有      無   2800000    7035.0   NaN         0.00        0
# 184         有      無    400000    4995.0   NaN         0.00        0
# 185         有      無   5600000   66477.0   NaN         0.00        0
# 186         有      無   5156000    5598.0   NaN         0.00        0
# 187         有      無    900000    2350.0   NaN         0.00        0
# 188         有      無   1816000   10590.0   NaN         0.00        0
# 189         有      無   1861000    3024.0   NaN         0.00        0
# 190         有      無   9000000   10353.0   NaN         0.00        0
# 191         有      無   1720000    2267.0   NaN         0.00        0
# 192         有      無   5260000   38227.0   NaN         0.00        0
# 193         有      無  13000000   95729.0   NaN         0.00        0
# 194         有      無   1000000    3519.0   NaN         0.00        0
# 0           有      無    312926    4700.0   NaN         0.00        0
# 1           有      無   1160231    3959.0   NaN         0.00        0
# 2           有      無    411955    4700.0   NaN         0.00        0
# 3           有      無    450000    4095.0   NaN         0.00        0
# 4           有      無    121382    5739.0   NaN         0.00        0
# 5           有      無      3380     847.0   NaN         0.00        0
# 6           有      無    229197    5655.0   NaN         0.00        0
#
#                                          備註                   編號
# 0                                     二親等買賣  RPQNMLRJKHMFFAA37CA
# 1               親友、員工或其他特殊關係間之交易。含增建或未登記建物。  RPUNMLMJKHMFFAA27CA
# 2                                含增建或未登記建物。  RPPRMLTJKHMFFAA87CA
# 3                                       NaN  RPSOMLPKKHMFFAA57CA
# 4                                含增建或未登記建物。  RPSNMLQJKHMFFBA57CA
# 5                                含增建或未登記建物。  RPTNMLRJKHMFFBA77CA
# 6                                       NaN  RPSNMLPKKHMFFBA57CA
# 7                         共有人數2人。含增建或未登記建物。  RPSPMLQJKHMFFCA87CA
# 8                            價格含增建或未辦保存登記建物  RPQOMLQJKHMFFCA57CA
# 9                                       NaN  RPORMLRJKHMFFCA77CA
# 10                                      NaN  RPOOMLTJKHMFFCA67CA
# 11                                      NaN  RPUOMLKKKHMFFCA47CA
# 12                                      NaN  RPPPMLPKKHMFFCA57CA
# 13                                      NaN  RPWOMLSKKHMFFCA48CA
# 14                                     陽台外推  RPVPMLNLKHMFFCA08CA
# 15                                      NaN  RPXOMLLJLHMFFCA87CA
# 16                               含增建或未登記建物。  RPSNMLQJKHMFFDA77CA
# 17              含增建或未登記建物。內含獨立產權車位，未包含在棟數內。  RPPOMLQJKHMFFDA57CA
# 18                               含增建或未登記建物。  RPTOMLQJKHMFFDA97CA
# 19                               含增建或未登記建物。  RPWOMLQJKHMFFDA28CA
# 20                                      NaN  RPXOMLQJKHMFFDA38CA
# 21                               含增建或未登記建物。  RPPPMLQJKHMFFDA67CA
# 22                        共有人數2人。含增建或未登記建物。  RPPQMLQJKHMFFDA77CA
# 23                親友、員工或其他特殊關係間之交易。登記兩人持分共有  RPXNMLRJKHMFFDA38CA
# 24                               含增建或未登記建物。  RPVRMLRJKHMFFDA58CA
# 25                                      NaN  RPQPMLSJKHMFFDA97CA
# 26                                      NaN  RPXNMLOKKHMFFDA18CA
# 27                                      NaN  RPPNMLMLKHMFFDA27CA
# 28                                      NaN  RPWNMLNJLHMFFDA97CA
# 29   內含獨立產權車位，未包含在棟數內。本案車位面積無法概算。含增建或未登記建物。  RPRNMLNJKHMFFEA47CA
# ..                                      ...                  ...
# 172   澎11號線(鼎灣-成功)道路拓寬工程協議價購(遊憩用地7,000元/M2)  RPUNMLLLMHMFFAX27CA
# 173                                     NaN  RPPNMLLLMHMFFAX76CA
# 174                                     NaN  RPWNMLPLMHMFFAX87CA
# 175                                     NaN  RPRNMLOLMHMFFAX27CA
# 176                                     NaN  RPPNMLPLMHMFFAX27DA
# 177                                     NaN  RPPNMLOJNHMFFAX07DA
# 178   澎11號線(鼎灣-成功)道路拓寬工程協議價購(遊憩用地7,000元/M2)  RPVNMLLLMHMFFAX37CA
# 179   澎11號線(鼎灣-成功)道路拓寬工程協議價購(遊憩用地7,000元/M2)  RPWNMLLLMHMFFAX47CA
# 180                                     NaN  RPPNMLOLMHMFFAX17DA
# 181                       親友、員工或其他特殊關係間之交易。  RPQNMLQLMHMFFAX57EA
# 182                                     NaN  RPTNMLPLMHMFFAX67DA
# 183                                     NaN  RPPNMLQLMHMFFAX37DA
# 184                                     NaN  RPPNMLRLMHMFFAX37CA
# 185                                     NaN  RPSNMLPLMHMFFAX47CA
# 178       鄉村區    乙種建築用地  1060418  土地3建物0車位0         ...                 0
# 179       鄉村區    乙種建築用地  1060418  土地3建物0車位0         ...                 0
# 180     一般農業區      農牧用地  1060313  土地1建物0車位0         ...                 0
# 181     一般農業區      農牧用地  1060407  土地1建物0車位0         ...                 0
# 182     一般農業區      農牧用地  1060419  土地1建物0車位0         ...                 0
# 183     一般農業區      農牧用地  1060412  土地7建物0車位0         ...                 0
# 184     一般農業區      農牧用地  1060408  土地1建物0車位0         ...                 0
# 185       NaN       NaN  1060411  土地1建物1車位0         ...                 2
# 186     一般農業區      農牧用地  1060323  土地1建物0車位0         ...                 0
# 187       鄉村區    乙種建築用地  1060331  土地1建物0車位0         ...                 0
# 188     一般農業區      農牧用地  1060414  土地2建物0車位0         ...                 0
# 189       風景區      農牧用地  1060403  土地2建物0車位0         ...                 0
# 190     一般農業區      農牧用地  1060413  土地1建物0車位0         ...                 0
# 191     一般農業區      農牧用地  1060419  土地1建物0車位0         ...                 0
# 192       NaN       NaN  1060321  土地1建物1車位0         ...                 3
# 193       NaN       NaN  1060410  土地4建物1車位0         ...                 3
# 194     一般農業區      農牧用地  1060411  土地2建物0車位0         ...                 0
# 0         NaN       NaN  1060202  土地1建物0車位0         ...                 0
# 1         NaN       NaN  1060221  土地2建物0車位0         ...                 0
# 2         NaN       NaN  1060221  土地1建物0車位0         ...                 0
# 3         NaN       NaN  1060327  土地1建物0車位0         ...                 0
# 4         NaN       NaN  1060327  土地1建物0車位0         ...                 0
# 5         NaN       NaN  1060324  土地1建物0車位0         ...                 0
# 6         NaN       NaN  1060331  土地1建物0車位0         ...                 0
#
#     建物現況格局-隔間 有無管理組織       總價元   單價每平方公尺  車位類別  車位移轉總面積平方公尺    車位總價元  \
# 0           無      無   7710000  241996.0   NaN         0.00        0
# 1           有      無  11300000  108654.0   NaN         0.00        0
# 2           有      有  29680000  236701.0   NaN         0.00        0
# 3           有      有   1300000       NaN  坡道機械        15.84  1300000
# 4           有      有  27500000  227104.0   NaN         0.00        0
# 5           有      無  22080000  140530.0   NaN         0.00        0
# 6           無      無  78500000  302036.0  坡道平面        91.27  6700000
# 7           有      有  10600000  138635.0   NaN         0.00        0
# 8           有      有  10400000  157887.0   NaN         0.00        0
# 9           有      無   7300000  172863.0   NaN         0.00        0
# 10          無      有  32900000  311818.0  坡道平面        52.71  2900000
# 11          有      有  15680000   90333.0  坡道平面         0.00        0
# 12          有      有   1500000       NaN  坡道平面        31.40  1500000
# 13          有      無  23800000  170744.0  坡道機械         0.00        0
# 14          有      有   5100000  141392.0   NaN         0.00        0
# 15          有      有  23000000  208768.0  坡道平面         0.00        0
# 16          有      有   7100000  187781.0   NaN         0.00        0
# 17          有      有  13000000  230824.0  坡道機械         0.00        0
# 18          有      有  20160000  197106.0   NaN         0.00        0
# 19          有      有  14260000  178652.0   NaN         0.00        0
# 20          有      有  26200000  192251.0   NaN         0.00        0
# 21          有      有  23400000  181522.0   NaN         0.00        0
# 22          有      無  11080000  154017.0   NaN         0.00        0
# 23          無      無  25000000  225958.0   NaN         0.00        0
# 24          有      無  14660000  153846.0   NaN         0.00        0
# 25          有      有  21000000  163386.0   NaN         0.00        0
# 26          有      無  13000000  204370.0   NaN         0.00        0
# 27          有      有  25000000  156671.0  坡道平面         0.00        0
# 28          無      有  37255000  208268.0   NaN         0.00        0
# 29          有      有  27500000  141098.0  坡道平面         0.00        0
# ..        ...    ...       ...       ...   ...          ...      ...
# 172         有      無      7355    7005.0   NaN         0.00        0
# 173         有      無  31000000  119231.0   NaN         0.00        0
# 174         有      無   2700000    1796.0   NaN         0.00        0
# 175         有      無   3360000   35733.0   NaN         0.00        0
# 176         有      無   9000000   32835.0   NaN         0.00        0
# 177         有      無  28800000  190011.0   NaN         0.00        0
# 178         有      無      7355    7005.0   NaN         0.00        0
# 179         有      無      7355    7005.0   NaN         0.00        0
# 180         有      無   7480000    6022.0   NaN         0.00        0
# 181         有      無   1000000    3246.0   NaN         0.00        0
# 182         有      無   2740000    3739.0   NaN         0.00        0
# 183         有      無   2800000    7035.0   NaN         0.00        0
# 184         有      無    400000    4995.0   NaN         0.00        0
# 185         有      無   5600000   66477.0   NaN         0.00        0
# 186         有      無   5156000    5598.0   NaN         0.00        0
# 187         有      無    900000    2350.0   NaN         0.00        0
# 188         有      無   1816000   10590.0   NaN         0.00        0
# 189         有      無   1861000    3024.0   NaN         0.00        0
# 190         有      無   9000000   10353.0   NaN         0.00        0
# 191         有      無   1720000    2267.0   NaN         0.00        0
# 192         有      無   5260000   38227.0   NaN         0.00        0
# 193         有      無  13000000   95729.0   NaN         0.00        0
# 194         有      無   1000000    3519.0   NaN         0.00        0
# 0           有      無    312926    4700.0   NaN         0.00        0
# 1           有      無   1160231    3959.0   NaN         0.00        0
# 2           有      無    411955    4700.0   NaN         0.00        0
# 3           有      無    450000    4095.0   NaN         0.00        0
# 4           有      無    121382    5739.0   NaN         0.00        0
# 5           有      無      3380     847.0   NaN         0.00        0
# 6           有      無    229197    5655.0   NaN         0.00        0
#
#                                          備註                   編號
# 0                                     二親等買賣  RPQNMLRJKHMFFAA37CA
# 1               親友、員工或其他特殊關係間之交易。含增建或未登記建物。  RPUNMLMJKHMFFAA27CA
# 2                                含增建或未登記建物。  RPPRMLTJKHMFFAA87CA
# 3                                       NaN  RPSOMLPKKHMFFAA57CA
# 4                                含增建或未登記建物。  RPSNMLQJKHMFFBA57CA
# 5                                含增建或未登記建物。  RPTNMLRJKHMFFBA77CA
# 6                                       NaN  RPSNMLPKKHMFFBA57CA
# 7                         共有人數2人。含增建或未登記建物。  RPSPMLQJKHMFFCA87CA
# 8                            價格含增建或未辦保存登記建物  RPQOMLQJKHMFFCA57CA
# 9                                       NaN  RPORMLRJKHMFFCA77CA
# 10                                      NaN  RPOOMLTJKHMFFCA67CA
# 11                                      NaN  RPUOMLKKKHMFFCA47CA
# 12                                      NaN  RPPPMLPKKHMFFCA57CA
# 13                                      NaN  RPWOMLSKKHMFFCA48CA
# 14                                     陽台外推  RPVPMLNLKHMFFCA08CA
# 15                                      NaN  RPXOMLLJLHMFFCA87CA
# 16                               含增建或未登記建物。  RPSNMLQJKHMFFDA77CA
# 17              含增建或未登記建物。內含獨立產權車位，未包含在棟數內。  RPPOMLQJKHMFFDA57CA
# 18                               含增建或未登記建物。  RPTOMLQJKHMFFDA97CA
# 19                               含增建或未登記建物。  RPWOMLQJKHMFFDA28CA
# 20                                      NaN  RPXOMLQJKHMFFDA38CA
# 21                               含增建或未登記建物。  RPPPMLQJKHMFFDA67CA
# 22                        共有人數2人。含增建或未登記建物。  RPPQMLQJKHMFFDA77CA
# 23                親友、員工或其他特殊關係間之交易。登記兩人持分共有  RPXNMLRJKHMFFDA38CA
# 24                               含增建或未登記建物。  RPVRMLRJKHMFFDA58CA
# 25                                      NaN  RPQPMLSJKHMFFDA97CA
# 26                                      NaN  RPXNMLOKKHMFFDA18CA
# 27                                      NaN  RPPNMLMLKHMFFDA27CA
# 28                                      NaN  RPWNMLNJLHMFFDA97CA
# 29   內含獨立產權車位，未包含在棟數內。本案車位面積無法概算。含增建或未登記建物。  RPRNMLNJKHMFFEA47CA
# ..                                      ...                  ...
# 172   澎11號線(鼎灣-成功)道路拓寬工程協議價購(遊憩用地7,000元/M2)  RPUNMLLLMHMFFAX27CA
# 173                                     NaN  RPPNMLLLMHMFFAX76CA
# 174                                     NaN  RPWNMLPLMHMFFAX87CA
# 175                                     NaN  RPRNMLOLMHMFFAX27CA
# 176                                     NaN  RPPNMLPLMHMFFAX27DA
# 177                                     NaN  RPPNMLOJNHMFFAX07DA
# 178   澎11號線(鼎灣-成功)道路拓寬工程協議價購(遊憩用地7,000元/M2)  RPVNMLLLMHMFFAX37CA
# 179   澎11號線(鼎灣-成功)道路拓寬工程協議價購(遊憩用地7,000元/M2)  RPWNMLLLMHMFFAX47CA
# 180                                     NaN  RPPNMLOLMHMFFAX17DA
# 181                       親友、員工或其他特殊關係間之交易。  RPQNMLQLMHMFFAX57EA
# 182                                     NaN  RPTNMLPLMHMFFAX67DA
# 183                                     NaN  RPPNMLQLMHMFFAX37DA
# 184                                     NaN  RPPNMLRLMHMFFAX37CA
# 185                                     NaN  RPSNMLPLMHMFFAX47CA
# 186                                     NaN  RPUNMLPLMHMFFAX67CA
# 187                       親友、員工或其他特殊關係間之交易。  RPPNMLRKNHMFFAX37CA
# 188                                     NaN  RPRNMLSLMHMFFAX77DA
# 189                                     NaN  RPPNMLLJNHMFFAX66CA
# 190                                     NaN  RPPNMLSLMHMFFAX47CA
# 191                                     NaN  RPTNMLSLMHMFFAX87CA
# 192                                     NaN  RPPNMLLKNHMFFAX76CA
# 193                                     NaN  RPQNMLLJNHMFFAX76CA
# 194                                     NaN  RPPNMLNJNHMFFAX96DA
# 0                                    含未登記建物  RPPNMLSKKHMFFAZ47DA
# 1                                       NaN  RPPNMLRJLHMFFAZ37DA
# 2                                       NaN  RPQNMLRJLHMFFAZ47DA
# 3                                       NaN  RPPNMLLJNHMFFAZ96DA
# 4                                       NaN  RPPNMLPLMHMFFAZ47DA
# 5                                       NaN  RPPNMLRKMHMFFAZ57DA
# 6                                       NaN  RPPNMLTKMHMFFAZ77DA
#
# [66949 rows x 29 columns]
